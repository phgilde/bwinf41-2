# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
for name in ["result99.txt", "result999.txt", "result9999.txt", "result99999.txt", "result999999.txt", "result9999999.txt"]:
    with open(name) as f:
        lines = f.readlines()[2:-2]
        x = []
        y = []
        for line in lines:
            line = line.split(", ")
            x.append(float(line[0]))
            y.append(float(line[1]))
        plt.plot(x, y, label=name)
        #plt.yscale("log")
        plt.xscale("log")

plt.legend()

# %%
x = [2,3,4,5,6,7]
y = []
for name in ["result99.txt", "result999.txt", "result9999.txt", "result99999.txt", "result999999.txt", "result9999999.txt"]:
    with open(name) as f:
        line = f.readlines()[-3]
        print(line)
        line = line.split(", ")
        y.append(float(line[1]))

plt.scatter(x, y)
# Out:
# 100000000, 2095.649479058483, 00:02:32
#
# 100000000, 1889.6306748359427, 00:02:22
#
# 100000000, 1903.699008693768, 00:02:22
#
# 100000000, 1991.1358974246475, 00:02:20
#
# 100000000, 1768.4695565283923, 00:02:21
#
# 100000000, 1755.9152326204862, 00:02:23
